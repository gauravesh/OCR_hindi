# %%
import pytesseract
from PIL import Image

# %%
image_file='GATE SYLLABUS.jpg'

# %%
Image.open(image_file)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=593x857>

# %%
ocr_result = pytesseract.image_to_string(image_file)

# %%
print(ocr_result)
# Out:
# Pte earerey oifParerar Uefa 2oRy
#
# GRADUATE APTITUDE TEST IN ENGINEERING 2024 @
#
# GATE New Test Paper on (DA) Data Science and Artificial Intelligence
# syllabus
#
# Probability and Statistics: Counting (permutation and combinations), probability axioms, Sample
# space, events, independent events, mutually exclusive events, marginal, conditional and joint
# probability, Bayes Theorem, conditional expectation and variance, mean, median, mode and standard
# ‘deviation, correlation, and covariance, random variables, discrete random variables and probability
# ‘mass functions, uniform, Bernoull, binomial distribution, Continuous random variables and
# Probability distribution function, uniform, exponential, Poisson, normal, standard normal,
# ‘distribution, chi-squared distributions, cumulative distribution function, Conditional PDF, Central
# limit theorem, confidence interval, 2-test, t-test, chi-squared test.
#
# ...

# %%
ocr_result
# Out:
# 'Pte earerey oifParerar Uefa 2oRy\n\nGRADUATE APTITUDE TEST IN ENGINEERING 2024 @\n\nGATE New Test Paper on (DA) Data Science and Artificial Intelligence\nsyllabus\n\nProbability and Statistics: Counting (permutation and combinations), probability axioms, Sample\nspace, events, independent events, mutually exclusive events, marginal, conditional and joint\nprobability, Bayes Theorem, conditional expectation and variance, mean, median, mode and standard\n‘deviation, correlation, and covariance, random variables, discrete random variables and probability\n‘mass functions, uniform, Bernoull, binomial distribution, Continuous random variables and\nProbability distribution function, uniform, exponential, Poisson, normal, standard normal,\n‘distribution, chi-squared distributions, cumulative distribution function, Conditional PDF, Central\nlimit theorem, confidence interval, 2-test, t-test, chi-squared test.\n\nnear Algebra: Vector space, subspaces, linear dependence and independence of ve
# ...
